# %% [markdown]
# # Data Wrangling 1

# %% [markdown]
# **Import pandas and read the data into the pandas data frame**

# %%
import pandas as pd
data = pd.read_csv('/content/total_netflix_2023 new.csv')

data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18332 entries, 0 to 18331
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                18332 non-null  object
#  1   Available Globally?  18332 non-null  object
#  2   Release Date         18332 non-null  object
#  3   Hours Viewed         18332 non-null  object
#  4   Number of Ratings    18332 non-null  object
#  5   Rating               18332 non-null  object
#  6   Genre                18332 non-null  object
#  7   Key Words            18332 non-null  object
#  8   Description          18332 non-null  object
# dtypes: object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# **Data Preprocessing**

# %% [markdown]
# *Check if data is null*

# %%
data.isnull()
# Out:
#        Title  Available Globally?  Release Date  Hours Viewed  \
# 0      False                False         False         False
# 1      False                False         False         False
# 2      False                False         False         False
# 3      False                False         False         False
# 4      False                False         False         False
# ...      ...                  ...           ...           ...
# 18327  False                False         False         False
# 18328  False                False         False         False
# 18329  False                False         False         False
# 18330  False                False         False         False
# 18331  False                False         False         False
#
#        Number of Ratings  Rating  Genre  Key Words  Description
# 0                  False   False  False      False        False
# 1                  False   False  False      False        False
# ...

# %% [markdown]
# *Describe the data*

# %%
data.describe()
# Out:
#                                      Title Available Globally? Release Date  \
# count                                18332               18332        18332
# unique                               18214                   2         1667
# top     Perfect Strangers // Známi neznámi                  No            0
# freq                                     4               13798         3693
#
#        Hours Viewed Number of Ratings Rating       Genre Key Words Description
# count         18332             18332  18332       18332     18332       18332
# unique          587              2267     82         394      2337        1900
# top               0           11869.0    6.6  ['Comedy']         0           0
# freq           3693               500    735        1560      2973         141

# %% [markdown]
# *Check the dimensions of the data*

# %%
data.size
# Out:
# 164988

# %% [markdown]
# Check the type of the datas

# %%
data_types = data.dtypes
print(data_types)
# Out:
# Title                  object
# Available Globally?    object
# Release Date           object
# Hours Viewed           object
# Number of Ratings      object
# Rating                 object
# Genre                  object
# Key Words              object
# Description            object
# dtype: object

# %%
data.values
# Out:
# array([['The Night Agent: Season 1', 'Yes', '2023-03-23', ...,
#         'Biography, Drama, History',
#         'persian empire,empire,5th century b.c.,achaemenid empire,persia',
#         'The film follows headstrong Ginny who meets Sunny for an arranged marriage, but turns him down, and then shows how Sunny teams up with Ginny&apos;s mother to win her love.'],
#        ['Ginny & Georgia: Season 2', 'Yes', '2023-01-05', ...,
#         'Comedy, Drama,Romance',
#         'producer,three word title,headstrong,arranged marriage,mother',
#         'Betrothed against her will to King George, young Charlotte arrives in London on her wedding day and faces scrutiny from the monarch&apos;s cunning mother.'],
#        ['The Glory: Season 1 // 더 글로리: 시즌 1', 'Yes', '2022-12-30', ...,
#         "['Short']",
#         'prequel,queen,historical,england,queen charlotte character',
# ...
